# %% [markdown]
# # **Image Captioning** demo

# %%
from model import ImageCaptioning

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 1. Prepare data

# %%
sample_image = "https://cdn.shopify.com/s/files/1/1409/0704/products/1_GG_123_1600_2000_gibson_1024x1024.jpg"

# %%
from IPython import display
display.Image(sample_image)

# %% [markdown]
# ### 2. Run a model

# %%
image_captioning = ImageCaptioning()
output = image_captioning.run(sample_image)

print(f"response: {output}")
# Out:
# response: a person holding a guitar in their hand
